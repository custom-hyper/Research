# %% [markdown]
# <a href="https://colab.research.google.com/github/custom-hyper/Research/blob/main/fearIndex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Next Steps
# * Add price of space on Coin Metrics
# * Run correlation analysis

# %%
#@title
# !pip install requests
# !pip install json
# !pip install datetime
# !pip install pylab
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json
# ...
#      |████████████████████████████████| 51 kB 240 kB/s
# ...
#      |████████████████████████████████| 251 kB 10.9 MB/s
# ...
# ERROR: Could not find a version that satisfies the requirement pylab (from versions: none)
# ERROR: No matching distribution found for pylab

# %% [markdown]
# Graph

# %%
#@title
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

sns.set_theme(style="darkgrid")

#Choose the date range
df_fear_greed = df_fear_greed[(df_fear_greed['date'] > '2018-06-27')]

df_fear_greed['value'] = df_fear_greed['value'].astype(int)
 
plt.figure(figsize=(20, 5))

sns.lineplot(data=df_fear_greed, linewidth=2.5, x="date", y="value", sort=False)
#sns.lineplot(data=df, linewidth=2.5, x="date", y="TotalCapMrktCurUSD")
plt.title('Crypto Fear & Greed Index Score')

plt.xticks(rotation=45)

plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# No handles with labels found to put in legend.

# %%
#@title
df_fear_greed['value'].describe()
# Out:
# count    1363.000000
# mean       46.360235
# std        23.032221
# min         5.000000
# 25%        27.000000
# 50%        42.000000
# 75%        65.500000
# max        95.000000
# Name: value, dtype: float64

# %%
sns.displot(df_fear_greed, x="value", kind="ecdf")

plt.title('ECDF of Crypto Fear & Greed Index')
# Out:
# Text(0.5, 1.0, 'ECDF of Crypto Fear & Greed Index')

# %%
#@title
start_date = '2020-06-27'
end_date = df1['date'].head(1)


df_class = df1[(df1['date'] > start_date)]

sns.catplot(x="value_classification", kind="count", palette="Blues", data=df_class)
plt.xticks(rotation=45)
sns.color_palette("Blues", as_cmap=True)
plt.title('Score Distribution ({} – {})'.format(start_date,'Today'))
# Out:
# Text(0.5, 1.0, 'Score Distribution (2020-06-27 – Today)')

# %%
#@title

sns.displot(df_class, x="value", kde=True, bins=25)
